# %% [markdown]
# # HTML Tabla de Precios de Habitaciones de Hotel
#
# Modelo de Tabla para Incorporar al Section Precios:
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link href="styles.css" rel="stylesheet" type="text/css">
#     <title>Tabla de Precios - Hotel</title>
# </head>
# <body>
#     <h1>Precios de Habitaciones</h1>
#     <table class="tabla-precios">
#         <thead>
#             <tr>
#                 <th>Tipo de Habitación</th>
#                 <th>Número de Personas</th>
#                 <th>Precio por Noche</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>Habitación Individual</td>
#                 <td>1</td>
#                 <td>$50</td>
#             </tr>
#             <tr>
#                 <td>Habitación Doble</td>
#                 <td>2</td>
#                 <td>$90</td>
#             </tr>
#             <tr>
#                 <td>Habitación Familiar</td>
#                 <td>4</td>
#                 <td>$150</td>
#             </tr>
#             <tr>
#                 <td>Suite</td>
#                 <td>2</td>
#                 <td>$200</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# </html>

# %% [markdown]
# # CSS Tabla de Precios de Habitaciones de Hotel
#
# Modelo de CSS para dar formato a precios:
# ```CSS
#
#         .tabla-precios {
#             width: 80%;
#             margin: 0 auto;
#             border-collapse: collapse;
#             background-color: #ffffff;
#         }
#         .tabla-precios th, .tabla-precios td {
#             border: 1px solid #b0b0b0;
#             padding: 10px;
#             text-align: center;
#         }
#         .tabla-precios th {
#             background-color: #004a8f;
#             color: #ffffff;
#         }
#         .tabla-precios tr:nth-child(even) {
#             background-color: #eaf4ff;
#         }
#         .tabla-precios tr:hover {
#             background-color: #d1e7ff;
#         }
